# %%
import pandas as pd

nba = pd. read_excel('Nba Teams.xlsx')
nba
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G    6'6   220.0
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G    NaN   180.0
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F    6'9   240.0
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F    6'8   218.0
# 4         Clint Capela       Atlanta Hawks  SouthEast        C   6'10   240.0
# ..                 ...                 ...        ...      ...    ...     ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 494                NaN                 NaN        NaN      NaN    NaN     NaN
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        484 non-null    object
#  1   Team        484 non-null    object
#  2   Division    484 non-null    object
#  3   Position    484 non-null    object
#  4   Height      470 non-null    object
#  5   Weight      484 non-null    float64
#  6   Birth_Date  484 non-null    datetime64[ns]
#  7   College     422 non-null    object
#  8   Salary      434 non-null    float64
#  9   Country     484 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 39.0+ KB

# %%
nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba.tail()
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 494                NaN                 NaN        NaN      NaN    NaN     NaN
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
#     Birth_Date  College      Salary Country
# 493 1998-02-08  Gonzaga   4692840.0      JP
# 494        NaT      NaN         NaN     NaN
# 495 1988-11-12     UCLA  41358814.0      US
# 496 1997-07-31  Indiana   8333333.0      US
# 497 1999-07-28   Oregon   3372840.0      US

# %%
nba.tail(7)
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 491          Raul Neto  Washington Wizards  SouthEast        G    6'1   180.0
# 492        Robin Lopez  Washington Wizards  SouthEast        C    7'0   281.0
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 494                NaN                 NaN        NaN      NaN    NaN     NaN
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
#     Birth_Date   College      Salary Country
# 491 1992-05-19       NaN   1882867.0      BR
# 492 1988-04-01  Stanford   7300000.0      US
# 493 1998-02-08   Gonzaga   4692840.0      JP
# 494        NaT       NaN         NaN     NaN
# 495 1988-11-12      UCLA  41358814.0      US
# 496 1997-07-31   Indiana   8333333.0      US
# ...

# %%
nba["Name"]
# Out:
# 0      Bogdan Bogdanovic
# 1        Brandon Goodwin
# 2         Bruno Fernando
# 3            Cam Reddish
# 4           Clint Capela
#              ...
# 493        Rui Hachimura
# 494                  NaN
# 495    Russell Westbrook
# 496        Thomas Bryant
# 497       Troy Brown Jr.
# Name: Name, Length: 498, dtype: object

# %%
nba["Salary"]
# Out:
# 0      18000000.0
# 1       1701593.0
# 2       1517981.0
# 3             NaN
# 4      16000000.0
#           ...
# 493     4692840.0
# 494           NaN
# 495    41358814.0
# 496     8333333.0
# 497     3372840.0
# Name: Salary, Length: 498, dtype: float64

# %%
nba.Name
# Out:
# 0      Bogdan Bogdanovic
# 1        Brandon Goodwin
# 2         Bruno Fernando
# 3            Cam Reddish
# 4           Clint Capela
#              ...
# 493        Rui Hachimura
# 494                  NaN
# 495    Russell Westbrook
# 496        Thomas Bryant
# 497       Troy Brown Jr.
# Name: Name, Length: 498, dtype: object

# %%
nba.Salary
# Out:
# 0      18000000.0
# 1       1701593.0
# 2       1517981.0
# 3             NaN
# 4      16000000.0
#           ...
# 493     4692840.0
# 494           NaN
# 495    41358814.0
# 496     8333333.0
# 497     3372840.0
# Name: Salary, Length: 498, dtype: float64

# %%
nba.College
# Out:
# 0                  NaN
# 1      Central Florida
# 2             Maryland
# 3                 Duke
# 4                  NaN
#             ...
# 493            Gonzaga
# 494                NaN
# 495               UCLA
# 496            Indiana
# 497             Oregon
# Name: College, Length: 498, dtype: object

# %%
nba[['Name', 'Team','Salary']]
# Out:
#                   Name                Team      Salary
# 0    Bogdan Bogdanovic       Atlanta Hawks  18000000.0
# 1      Brandon Goodwin       Atlanta Hawks   1701593.0
# 2       Bruno Fernando       Atlanta Hawks   1517981.0
# 3          Cam Reddish       Atlanta Hawks         NaN
# 4         Clint Capela       Atlanta Hawks  16000000.0
# ..                 ...                 ...         ...
# 493      Rui Hachimura  Washington Wizards   4692840.0
# 494                NaN                 NaN         NaN
# 495  Russell Westbrook  Washington Wizards  41358814.0
# 496      Thomas Bryant  Washington Wizards   8333333.0
# 497     Troy Brown Jr.  Washington Wizards   3372840.0
#
# [498 rows x 3 columns]

# %%
nba[['Name', 'Team','Salary']].head()
# Out:
#                 Name           Team      Salary
# 0  Bogdan Bogdanovic  Atlanta Hawks  18000000.0
# 1    Brandon Goodwin  Atlanta Hawks   1701593.0
# 2     Bruno Fernando  Atlanta Hawks   1517981.0
# 3        Cam Reddish  Atlanta Hawks         NaN
# 4       Clint Capela  Atlanta Hawks  16000000.0

# %%
nba[['Name', 'Team','Salary']].tail()
# Out:
#                   Name                Team      Salary
# 493      Rui Hachimura  Washington Wizards   4692840.0
# 494                NaN                 NaN         NaN
# 495  Russell Westbrook  Washington Wizards  41358814.0
# 496      Thomas Bryant  Washington Wizards   8333333.0
# 497     Troy Brown Jr.  Washington Wizards   3372840.0

# %%
nba2 = nba[['Name', 'Team','Salary']].tail()
nba2
# Out:
#                   Name                Team      Salary
# 493      Rui Hachimura  Washington Wizards   4692840.0
# 494                NaN                 NaN         NaN
# 495  Russell Westbrook  Washington Wizards  41358814.0
# 496      Thomas Bryant  Washington Wizards   8333333.0
# 497     Troy Brown Jr.  Washington Wizards   3372840.0

# %%
nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba["nbaTeams"] = "NBA"
nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country nba teams nbaTeams
# 0 1992-08-18              NaN  18000000.0      RS       NBA      NBA
# 1 1995-10-02  Central Florida   1701593.0      US       NBA      NBA
# 2 1998-08-15         Maryland   1517981.0      AO       NBA      NBA
# 3 1999-09-01             Duke         NaN      US       NBA      NBA
# 4 1994-05-18              NaN  16000000.0      CH       NBA      NBA

# %%
nba.nbaTeams
# Out:
# 0      NBA
# 1      NBA
# 2      NBA
# 3      NBA
# 4      NBA
#       ...
# 493    NBA
# 494    NBA
# 495    NBA
# 496    NBA
# 497    NBA
# Name: nbaTeams, Length: 498, dtype: object

# %%
nba["Sports"] = "Basketball"
nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country nba teams nbaTeams  \
# 0 1992-08-18              NaN  18000000.0      RS       NBA      NBA
# 1 1995-10-02  Central Florida   1701593.0      US       NBA      NBA
# 2 1998-08-15         Maryland   1517981.0      AO       NBA      NBA
# 3 1999-09-01             Duke         NaN      US       NBA      NBA
# 4 1994-05-18              NaN  16000000.0      CH       NBA      NBA
#
#        Sports
# 0  Basketball
# 1  Basketball
# 2  Basketball
# 3  Basketball
# 4  Basketball

# %%
nba = pd. read_excel('Nba Teams.xlsx')
nba.head()
# Out:
#                 Name           Team   Division Position Height  Weight  \
# 0  Bogdan Bogdanovic  Atlanta Hawks  SouthEast        G    6'6   220.0
# 1    Brandon Goodwin  Atlanta Hawks  SouthEast        G    NaN   180.0
# 2     Bruno Fernando  Atlanta Hawks  SouthEast        F    6'9   240.0
# 3        Cam Reddish  Atlanta Hawks  SouthEast        F    6'8   218.0
# 4       Clint Capela  Atlanta Hawks  SouthEast        C   6'10   240.0
#
#   Birth_Date          College      Salary Country
# 0 1992-08-18              NaN  18000000.0      RS
# 1 1995-10-02  Central Florida   1701593.0      US
# 2 1998-08-15         Maryland   1517981.0      AO
# 3 1999-09-01             Duke         NaN      US
# 4 1994-05-18              NaN  16000000.0      CH

# %%
nba.insert(2, column = "Sports", value = "Basketball")
nba
# Out:
#                   Name                Team      Sports   Division Position  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  Basketball  SouthEast        G
# 1      Brandon Goodwin       Atlanta Hawks  Basketball  SouthEast        G
# 2       Bruno Fernando       Atlanta Hawks  Basketball  SouthEast        F
# 3          Cam Reddish       Atlanta Hawks  Basketball  SouthEast        F
# 4         Clint Capela       Atlanta Hawks  Basketball  SouthEast        C
# ..                 ...                 ...         ...        ...      ...
# 493      Rui Hachimura  Washington Wizards  Basketball  SouthEast        F
# 494                NaN                 NaN  Basketball        NaN      NaN
# 495  Russell Westbrook  Washington Wizards  Basketball  SouthEast        G
# 496      Thomas Bryant  Washington Wizards  Basketball  SouthEast        C
# 497     Troy Brown Jr.  Washington Wizards  Basketball  SouthEast      G-F
#
#     Height  Weight Birth_Date          College      Salary Country
# ...

# %%
nba.insert(2, column = "Sports", value = "Basketball", allow_duplicates = True)
nba
# Out:
#                   Name                Team      Sports      Sports   Division  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  Basketball  Basketball  SouthEast
# 1      Brandon Goodwin       Atlanta Hawks  Basketball  Basketball  SouthEast
# 2       Bruno Fernando       Atlanta Hawks  Basketball  Basketball  SouthEast
# 3          Cam Reddish       Atlanta Hawks  Basketball  Basketball  SouthEast
# 4         Clint Capela       Atlanta Hawks  Basketball  Basketball  SouthEast
# ..                 ...                 ...         ...         ...        ...
# 493      Rui Hachimura  Washington Wizards  Basketball  Basketball  SouthEast
# 494                NaN                 NaN  Basketball  Basketball        NaN
# 495  Russell Westbrook  Washington Wizards  Basketball  Basketball  SouthEast
# 496      Thomas Bryant  Washington Wizards  Basketball  Basketball  SouthEast
# 497     Troy Brown Jr.  Washington Wizards  Basketball  Basketball  SouthEast
#
# ...

# %%
nba.drop("Sports", axis = 1)
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G    6'6   220.0
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G    NaN   180.0
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F    6'9   240.0
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F    6'8   218.0
# 4         Clint Capela       Atlanta Hawks  SouthEast        C   6'10   240.0
# ..                 ...                 ...        ...      ...    ...     ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 494                NaN                 NaN        NaN      NaN    NaN     NaN
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
# ...

# %%
nba
# Out:
#                   Name                Team      Sports      Sports   Division  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  Basketball  Basketball  SouthEast
# 1      Brandon Goodwin       Atlanta Hawks  Basketball  Basketball  SouthEast
# 2       Bruno Fernando       Atlanta Hawks  Basketball  Basketball  SouthEast
# 3          Cam Reddish       Atlanta Hawks  Basketball  Basketball  SouthEast
# 4         Clint Capela       Atlanta Hawks  Basketball  Basketball  SouthEast
# ..                 ...                 ...         ...         ...        ...
# 493      Rui Hachimura  Washington Wizards  Basketball  Basketball  SouthEast
# 494                NaN                 NaN  Basketball  Basketball        NaN
# 495  Russell Westbrook  Washington Wizards  Basketball  Basketball  SouthEast
# 496      Thomas Bryant  Washington Wizards  Basketball  Basketball  SouthEast
# 497     Troy Brown Jr.  Washington Wizards  Basketball  Basketball  SouthEast
#
# ...

# %%
nba.drop("Sports", axis = 1, inplace = True)

# %%
nba
# Out:
#                   Name                Team   Division Position Height  Weight  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G    6'6   220.0
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G    NaN   180.0
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F    6'9   240.0
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F    6'8   218.0
# 4         Clint Capela       Atlanta Hawks  SouthEast        C   6'10   240.0
# ..                 ...                 ...        ...      ...    ...     ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F    6'8   230.0
# 494                NaN                 NaN        NaN      NaN    NaN     NaN
# 495  Russell Westbrook  Washington Wizards  SouthEast        G    6'3   200.0
# 496      Thomas Bryant  Washington Wizards  SouthEast        C   6'10   248.0
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F    6'6   215.0
#
# ...

# %%
nba.drop["Division", "Position", axis = 1, inplace = True)
